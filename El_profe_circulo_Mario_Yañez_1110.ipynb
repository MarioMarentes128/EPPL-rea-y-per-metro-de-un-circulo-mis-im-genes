# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioMarentes128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/El_profe_circulo_Mario_Ya%C3%B1ez_1110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Mario Yañez NL = 53 Fecha 25/mar/2026:: 🎈
# ---
# # Calcular Aarea y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/MarioMarentes128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/circulo_are_perimetro.PNG)
# ---
# ## Formula para calcular area
# $A=\pi*R^2$
# ---
# ## Formula para calcular el perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## DIagrama de flujo en Lucichart
# ![Logo de Markdown](https://raw.githubusercontent.com/MarioMarentes128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# Variables A,P, r
# Formulas A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor del radio: "))
A = math.pi *r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Mario Yañez NL = 53")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor del radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Mario Yañez NL = 53

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/MarioMarentes128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
